# %%
import main; reload(main);from main import *

# %%
get_all_artists_all_words_to_file()
# Out:
# artist.git
# artist2-chainz
# artist2pac
# artist50cent
# artista-tribe
# artistasap-rocky
# artistbeastie-boys
# artistbiggie
# artistdead-prez
# artistdr-dre
# artistdrake
# artisteminem
# artistfoxy-brown
# artistiggy-azalea
# artistimmortal-technique
# artistjay-z
# artistjcole
# artistkanye-west
# artistkendrick-lamar
# artistlil-jon
# artistlil-kim
# artistlil-wayne
# artistludacris
# artistmc-lyte
# artistmissy-elliott
# artistnas
# artistnicki-minaj
# artistnwa
# artistoutkast
# artistqueen-latifah
# artistsnoop-dogg
# artisttalib-kweli
# artistti
# artisttyga
# artistwu-tang
# 0.01123795	nigga
# 0.01053547	niggas
# 0.01046760	shit
# 0.00785575	fuck
# 0.00688364	bitch
# 0.00520721	time
# 0.00497793	love
# 0.00455057	wanna
# 0.00432497	money
# 0.00420208	life
# 0.00408286	tell
# 0.00360781	baby
# 0.00355462	gotta
# 0.00352711	ass
# 0.00329600	real
# 0.00314377	girl
# 0.00286681	hit
# 0.00283379	call
# 0.00280078	look
# 0.00265771	bitches

# %%
get_one_artist_all_words("kanye-west")
# Out:
# excludingkanye
# excludingwest
# 0.00877637	shit
# 0.00717300	niggas
# 0.00599156	nigga
# 0.00582278	time
# 0.00565401	love
# 0.00556962	tell
# 0.00548523	baby
# 0.00540084	money
# 0.00506329	girl
# 0.00472574	fuck
# 0.00430380	look
# 0.00421941	talking
# 0.00405063	people
# 0.00396624	life
# 0.00396624	told
# 0.00362869	black
# 0.00362869	feel
# 0.00362869	real
# 0.00345992	bout
# 0.00345992	day

# %%
make_exclude_names()
# Out:
# .git
# 2
# chainz
# 2pac
# 50cent
# a
# tribe
# asap
# rocky
# beastie
# boys
# biggie
# dead
# prez
# dr
# dre
# drake
# eminem
# foxy
# brown
# iggy
# azalea
# immortal
# technique
# jay
# z
# jcole
# kanye
# west
# kendrick
# lamar
# lil
# jon
# lil
# kim
# lil
# wayne
# ludacris
# mc
# lyte
# missy
# elliott
# nas
# nicki
# minaj
# nwa
# outkast
# queen
# latifah
# snoop
# dogg
# talib
# kweli
# ti
# tyga
# wu
# tang

# %%
get_one_artist_excluding_common("missy-elliott")
# Out:
# in here
# for artist: missy-elliott
# 0.00891632	shake
# 0.00658436	mommy
# 0.00589849	beat
# 0.00562414	boy
# 0.00548697	movin
# 0.00466392	doo
# 0.00466392	hot
# 0.00438957	move
# 0.00438957	stop
# 0.00425240	yes
# 0.00411523	play
# 0.00397805	break
# 0.00384088	pom
# 0.00370370	minute
# 0.00370370	misdemeanor
# 0.00370370	ooh
# 0.00370370	party
# 0.00370370	pass
# 0.00356653	fly
# 0.00342936	feel

# %%
get_one_artist_excluding_common("biggie")
# Out:
# in here
# for artist: biggie
# 0.00379651	mad
# 0.00354341	fuckin
# 0.00341686	dick
# 0.00335358	head
# 0.00329031	motherfucker
# 0.00322703	hoes
# 0.00303721	black
# 0.00303721	fucking
# 0.00297393	somethin
# 0.00284738	die
# 0.00272083	smoke
# 0.00265756	play
# 0.00259428	check
# 0.00259428	game
# 0.00259428	gonna
# 0.00259428	stop
# 0.00246773	beef
# 0.00246773	daddy
# 0.00246773	hard
# 0.00240445	day

# %%
get_one_artist_excluding_common("eminem")
# Out:
# in here
# for artist: eminem
# 0.00585149	fucking
# 0.00474173	little
# 0.00398507	shady
# 0.00327885	fuckin
# 0.00317797	boy
# 0.00302663	gonna
# 0.00297619	dick
# 0.00297619	feel
# 0.00282486	sick
# 0.00282486	world
# 0.00267353	head
# 0.00267353	try
# 0.00252220	day
# 0.00252220	leave
# 0.00237086	drop
# 0.00237086	stop
# 0.00232042	bad
# 0.00232042	mean
# 0.00232042	mother
# 0.00232042	people

# %%
get_each_artist_excluding_common()
# Out:
# for artist: 2-chainz
# 0.00521548	ho
# 0.00494098	head
# 0.00452923	pull
# 0.00425474	hoes
# 0.00425474	murder
# 0.00411749	bad
# 0.00411749	car
# 0.00398024	day
# 0.00398024	pussy
# 0.00356849	hard
# 0.00329399	birthday
# 0.00329399	die
# 0.00329399	top
# 0.00315674	fucking
# 0.00315674	told
# 0.00301949	boy
# 0.00301949	feel
# 0.00301949	hell
# 0.00301949	name
# 0.00301949	shawty
# for artist: 2pac
# 0.00615144	die
# 0.00570406	thug
# 0.00520076	motherfuckers
# 0.00497707	live
# 0.00464154	game
# 0.00458562	head
# 0.00452969	hard
# 0.00425008	world
# 0.00402640	gettin
# 0.00391455	hands
# 0.00391455	motherfucker
# 0.00385863	black
# 0.00385863	day
# 0.00385863	god
# 0.00380271	ride
# 0.00313164	death
# 0.00313164	mama
# 0.00307572	enemies
# 0.00307572	g
# 0.00307572	little
# for artist: 50cent
# 0.00562984	hot
# 0.00492611	little
# 0.00471499	hood
# 0.00450387	gonna
# 0.00422238	god
# 0.00415201	fuckin
# 0.00387051	head
# 0.00372977	talk
# 0.00365939	watch
# 0.00358902	run
# ...

# %%
get_each_artist_excluding_common()
# Out:
# for artist: 2-chainz
# 0.00506937	ho
# 0.00480256	head
# 0.00453575	bout
# 0.00440235	pull
# 0.00413554	hoes
# 0.00413554	murder
# 0.00400213	bad
# 0.00400213	car
# 0.00386873	day
# 0.00386873	pussy
# 0.00346852	bitches
# 0.00346852	hard
# 0.00320171	birthday
# 0.00320171	die
# 0.00320171	top
# 0.00306830	fucking
# 0.00306830	told
# 0.00293490	boy
# 0.00293490	feel
# 0.00293490	hell
# for artist: 2pac
# 0.00599194	die
# 0.00555616	thug
# 0.00506591	motherfuckers
# 0.00484802	live
# 0.00452119	game
# 0.00446672	head
# 0.00441225	hard
# 0.00413988	world
# 0.00408541	bitches
# 0.00392200	gettin
# 0.00381305	hands
# 0.00381305	motherfucker
# 0.00375858	black
# 0.00375858	day
# 0.00375858	god
# 0.00370411	ride
# 0.00305044	death
# 0.00305044	mama
# 0.00299597	dead
# 0.00299597	enemies
# for artist: 50cent
# 0.00544959	hot
# 0.00538147	wit
# 0.00476839	little
# 0.00456403	hood
# 0.00435967	gonna
# 0.00408719	god
# 0.00401907	fuckin
# 0.00374659	head
# 0.00361035	talk
# 0.00354223	watch
# ...

# %%
import rap_stats as rs

# %%
results = rs.count_for_all_artists()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-2dd2cb1149d5> in <module>()
# ----> 1 results = rs.count_for_all_artists()
#
# /Users/julielavoie/PycharmProjects/pycon/rap_stats.py in count_for_all_artists(dir, testing)
#      75             if re.search('\.git', artist):
#      76                 continue
# ---> 77             print "Artist " + artist
#      78             results[artist] = count_for_one_artist(artist)
#      79     return results
#
# /Users/julielavoie/PycharmProjects/pycon/rap_stats.py in count_for_one_artist(artist, bad_words)
#      87     file_list = make_song_list(artist)
#      88     for f in file_list:
# ---> 89
#      90         lyrics = scrape_lyrics_from_song(f)
#      91         song_name = os.path.basename(f)
#
# /Users/julielavoie/PycharmProjects/pycon/rap_stats.py in scrape_lyrics_from_song(file)
# ...

# %%
get_one_artist_excluding_common("iggy-azalea")
# Out:
# for artist: iggy-azalea
# 0.01079414	pussy
# 0.01002313	bitches
# 0.00616808	drop
# 0.00539707	hoes
# 0.00501157	times
# 0.00481881	change
# 0.00481881	world
# 0.00443331	bad
# 0.00443331	damn
# 0.00443331	red
# 0.00404780	gone
# 0.00404780	heart
# 0.00385505	bout
# 0.00385505	feel
# 0.00385505	gold
# 0.00385505	leave
# 0.00366230	die
# 0.00366230	haters
# 0.00366230	lay
# 0.00346955	bang

# %%
from rap_stats import *

# %%
get_one_artist_excluding_common("a-tribe")
# Out:
# for artist: a-tribe
# 0.00985631	phife
# 0.00546253	check
# 0.00546253	rock
# 0.00439378	dawg
# 0.00415628	gonna
# 0.00409690	mc
# 0.00380002	quest
# 0.00374065	cuz
# 0.00374065	tip
# 0.00368127	lyrics
# 0.00362190	word
# 0.00350315	start
# 0.00338440	people
# 0.00332502	beat
# 0.00326565	brothers
# 0.00326565	try
# 0.00308752	rhyme
# 0.00296877	rhymes
# 0.00285002	world
# 0.00267189	mind

# %%
scrape_lyrics_from_song("files/asap-rocky/A-ap-rocky-goldie-lyrics.html")
# Out:
# u' [Hook] I said it must be cause a nigga got dough Extraordinary swag and a mouth full of gold Hoes at my shows they be strippin\' off they clothes And them college girls write a nigga name on they toes Niggas talk shit \'til they get lockjaw Chrome to ya dome \'til ya get glockjaw Party like a cowboy or a rockstar Everybody play the tough guy \'til shit pop off  [Verse 1] Let\'s take it to the basis, you in the midst of greatness My Martin was a Maison, rocked Margielas with no laces Cristal go by the cases, wait hold up that was racist I would prefer the Aces, ain\'t no different when you taste it A 40 ounce to chase it, that\'s just a understatement I\'m early to the party, but my \'Rari is the latest Somehow it seems girls in they late teens Remind me your favorite jeans cause they naked cause you famous Life\'s a mothafucka, ain\'t it? These other rappers anus So tell me what your name is, I\'mma tell it to my stainless You aim it \'fore you bang it let that banger leave you br
# ...

# %%
from main import *
f = open("files/asap-rocky/A-ap-rocky-goldie-lyrics.html", 'r')
page = f.read()
dom = DOM(page)
lyrics =  dom('.lyrics')[0]
p = plaintext(lyrics.content)
print p
# Out:
# [Hook]
# I said it must be cause a nigga got dough
# Extraordinary swag and a mouth full of gold
# Hoes at my shows they be strippin' off they clothes
# And them college girls write a nigga name on they toes
# Niggas talk shit 'til they get lockjaw
# Chrome to ya dome 'til ya get glockjaw
# Party like a cowboy or a rockstar
# Everybody play the tough guy 'til shit pop off
#
# [Verse 1]
# Let's take it to the basis, you in the midst of greatness
# My Martin was a Maison, rocked Margielas with no laces
# Cristal go by the cases, wait hold up that was racist
# I would prefer the Aces, ain't no different when you taste it
# A 40 ounce to chase it, that's just a understatement
# I'm early to the party, but my 'Rari is the latest
# Somehow it seems girls in they late teens
# Remind me your favorite jeans cause they naked cause you famous
# Life's a mothafucka, ain't it? These other rappers anus
# So tell me what your name is, I'mma tell it to my stainless
# ...

# %%
reload(main); from main import *

# %%
make_exclude_names()
# Out:
# .git
# 2
# chainz
# 2pac
# 50cent
# a
# tribe
# asap
# rocky
# beastie
# boys
# biggie
# dead
# prez
# dr
# dre
# drake
# eminem
# foxy
# brown
# iggy
# azalea
# immortal
# technique
# jay
# z
# jcole
# kanye
# west
# kendrick
# lamar
# lil
# jon
# lil
# kim
# lil
# wayne
# ludacris
# mc
# lyte
# missy
# elliott
# nas
# nicki
# minaj
# nwa
# outkast
# queen
# latifah
# snoop
# dogg
# stop_names
# talib
# kweli
# ti
# tyga
# wu
# tang

# %%
reload(main); from main import *

# %%
load_exclude_names()

# %%
rap_stop_words
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-43d26694baee> in <module>()
# ----> 1 rap_stop_words
#
# NameError: name 'rap_stop_words' is not defined

# %%
print rap_exclude_words

# %%
from main import *

# %%
get_one_artist_excluding_common("iggy-azalea")
# Out:
# in here
# ['1', '2', '3', 'x2', 'ay', 'hey', 'cuz', "'mma", 'kanye', 'west', 'yo', 't', 'oh', 'uh', 'ya', 'la', 'gon', 'cause', 'em', 'yeah', '50', 'cent', 'nigga', 'niggas', 'shit', 'fuck', 'bitch', 'yo', 'time', 'love', 'wanna', 'money', 'life', 'tell', 'baby', 'ass', 'gotta', 'real', 'girl', 'hit', 'call', 'look', '']
# for artist: iggy-azalea
# 0.01507159	iggy
# 0.01055011	pussy
# 0.00979653	bitches
# 0.00810098	azalea
# 0.00602864	drop
# 0.00527506	hoes
# 0.00489827	times
# 0.00470987	change
# 0.00470987	world
# 0.00433308	bad
# 0.00433308	damn
# 0.00433308	red
# 0.00395629	gone
# 0.00395629	heart
# 0.00376790	bout
# 0.00376790	feel
# 0.00376790	gold
# 0.00376790	leave
# 0.00357950	die
# 0.00357950	haters

# %%
make_exclude_names()

# %%
print "foo"

# %%
print "foo"
# Out:
# foo

# %%
docs = get_artist_docs("iggy-azalea")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f9d5701f47c8> in <module>()
# ----> 1 docs = get_artist_docs("iggy-azalea")
#
# NameError: name 'get_artist_docs' is not defined

# %%
import main

# %%
docs = get_artist_docs("iggy-azalea")

# %%
from main import *

# %%
print docs
# Out:
# [Hook: Iggy Azalea]
# Motherfuckers calling my phone
# 1-800-Bone
# Boy, ain't you know?
# I can back it up like a tonka truck
# So call my phone phone
# 1-800-Bone
# Say you got that gun?
# That AK-47
# Bang! bang! bang!
#
# [Verse 1: Iggy Azalea]
# Iggy got that secret service this that presidential shit
# Get the busy tone when ya call my phone and my voicemail full of messages
# Say you got that AK-47 well let me see you shoot it
# Eat it up, beat it up boy don't bruise it
# Put ya hands on it don't slip don't lose it
# Bad bitches in my chat room, my chat room be poppin
# Turn that chat room to a freak show when them bad bitches get topless
# Put it on ustream for the whole world so the whole world can see it
# Got that hotline, and it's about time for me to swap it out, I gotta re-up
# They saying, "Iggy, oh, Iggy," they wanna play with that kitty
# They calling, blowing my phone up, wishing they could kick it with me
# ...

# %%
dic = vec.count(vec.words(docs), metric=tf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-87fb18e564e9> in <module>()
# ----> 1 dic = vec.count(vec.words(docs), metric=tf)
#
# NameError: name 'tf' is not defined

# %%
dic['bitch']
# Out:
# 92

# %%
reload(main); from main import *

# %%
count_one_artist("lil-jon", ['bitch'])
# Out:
# {'bitch': 377, 'num_songs': 200}

# %%
docs = vec.words(get_artist_docs("missy-elliott"))

# %%
print docs
# Out:
# [u'Fantasia', u'Like', u'your', u'name', u'is', u'MISSY', u'ELLIOTT', u'my', u'name', u'is', u'Fantasia', u'Barrino', u'And', u'what', u'I', u'can', u'GIVE', u'YOU', u'is', u'Fantasia', u'Barrino', u'Holla', u'at', u'your', u'girl', u'Missy', u'Two', u'thousand', u'five', u'WOOOOOOOOOOOO', u'Wake', u'up', u'in', u'the', u'mornin', u'with', u'my', u'man', u'next', u'to', u'me', u'Up', u'all', u'night', u'like', u'we', u"'ve", u'been', u'on', u'that', u'ecstasy', u'YES', u'Mixed', u'with', u'Hennessy', u'he', u'got', u'the', u'remedy', u'Yeah', u'my', u'nigga', u'into', u'me', u'I', u"can'", u't', u'say', u'it', u'simply', u'We', u'take', u'a', u'quick', u'shower', u'for', u'the', u'hour', u'conversation', u'Time', u'to', u'have', u'relation', u'love', u'makin', u'in', u'the', u'basement', u'Smack', u'it', u'up', u'flip', u'it', u'up', u'crush', u'it', u'One', u'minute', u'two', u'minute', u'I', u'was', u'no', u'question', u'AHH', u'Who', u'would', u'ever', u'think', u'that', u'I', u"'
# ...

# %%
count_one_artist("missy-elliott", ['bitch'])
# Out:
# {'bitch': 25, 'num_songs': 47}

# %%
len(os.listdir(default_dir))
# Out:
# 47

# %%
basedir = "/Users/julielavoie/projects/pycon/files/"

# %%
default_dir = basedir + "missy-elliott"

# %%
get_all_artist_all_words()
# Out:
# 0.01120364	nigga
# 0.01050330	niggas
# 0.01043564	shit
# 0.00783176	fuck
# 0.00686262	bitch
# 0.00519130	time
# 0.00496273	love
# 0.00453668	wanna
# 0.00431176	money
# 0.00418925	life
# 0.00407039	tell
# 0.00359679	baby
# 0.00354376	gotta
# 0.00351634	ass
# 0.00328594	real
# 0.00313417	girl
# 0.00285805	hit
# 0.00282514	call
# 0.00279222	look
# 0.00264960	bitches

# %%
from main import

# %%
get_all_artist_all_words()
# Out:
# 0.01120364	nigga
# 0.01050330	niggas
# 0.01043564	shit
# 0.00783176	fuck
# 0.00686262	bitch
# 0.00519130	time
# 0.00496273	love
# 0.00453668	wanna
# 0.00431176	money
# 0.00418925	life
# 0.00407039	tell
# 0.00359679	baby
# 0.00354376	gotta
# 0.00351634	ass
# 0.00328594	real
# 0.00313417	girl
# 0.00285805	hit
# 0.00282514	call
# 0.00279222	look
# 0.00264960	bitches
